# %% [markdown]
# # 0. Preparing the Data Access and Processing

# %% [markdown]
# Using the imports as shown in pyriksdagen project from Google Colab.

# %%
from lxml import etree
import progressbar
from pyparlaclarin.read import paragraph_iterator, speeches_with_name
from pyriksdagen.utils import protocol_iterators, download_corpus
import pyriksdagen
from pyriksdagen.metadata import load_Corpus_metadata
parser = etree.XMLParser(remove_blank_text=True)

# %% [markdown]
# Import the records corpus.

# %%
print(pyriksdagen.__spec__)
download_corpus(partitions=["records"])

# %% [markdown]
# # 1. Metadata introduction

# %% [markdown]
# Extract important metadata to carry out the logic in our approach.

# %%
df = load_Corpus_metadata("data")
# Out:
# Compiling metadata db from source.
#                       person_id       start   end  \
# 0      i-PFAPNmRqeUAaxDzNRTG1x1        1867  1867
# 1      i-QSYHiJ6G54WwZYYDpVnD4u        1867  1867
# 2      i-Ddmtm1uG9esPH37c8XjUXZ        1867  1867
# 3      i-65rmwEXkkhA1kxSrD4oMUw        1867  1867
# 4      i-AvGpsGJvs5PXTcEG4DtbFt        1867  1867
# ...                         ...         ...   ...
# 13218  i-NHEfCn32mEHrAw3JbShLAA  2024-04-22   NaN
# 13219  i-6GYXkbfSoUeH3CekfDuKLA  2024-05-01   NaN
# 13220  i-3y4o8soU9qx5tQQ1cG92h3  2024-05-02   NaN
# 13221   i-x1CuoKmRHYgQr9i2kh3B5         NaN   NaN
# 13222  i-TUyWWYGDFXW92GhiG3CLwF         NaN   NaN
#
#                                     district                 role
# 0          Eskilstuna och Strängnäs valkrets   andrakammarledamot
# 1      Västra Götalands läns västra valkrets  förstakammarledamot
# 2                      Torna härads valkrets   andrakammarledamot
# 3                    Värmlands läns valkrets  förstakammarledamot
# 4                Kristianstads läns valkrets  förstakammarledamot
# ...                                      ...                  ...
# 13218               Stockholms läns valkrets              ledamot
# 13219                  Uppsala läns valkrets              ledamot
# 13220                Jämtlands läns valkrets              ledamot
# 13221                                    NaN              ledamot
# 13222                                    NaN              ledamot
#
# [13223 rows x 5 columns]
#                       person_id       start   end  \
# 0      i-PFAPNmRqeUAaxDzNRTG1x1        1867  1867
# 1      i-QSYHiJ6G54WwZYYDpVnD4u        1867  1867
# 2      i-Ddmtm1uG9esPH37c8XjUXZ        1867  1867
# 3      i-65rmwEXkkhA1kxSrD4oMUw        1867  1867
# 4      i-AvGpsGJvs5PXTcEG4DtbFt        1867  1867
# ...                         ...         ...   ...
# 13219  i-NHEfCn32mEHrAw3JbShLAA  2024-04-22   NaN
# 13220  i-6GYXkbfSoUeH3CekfDuKLA  2024-05-01   NaN
# 13221  i-3y4o8soU9qx5tQQ1cG92h3  2024-05-02   NaN
# 13222   i-x1CuoKmRHYgQr9i2kh3B5         NaN   NaN
# 13223  i-TUyWWYGDFXW92GhiG3CLwF         NaN   NaN
#
#                                     district                 role  \
# 0          Eskilstuna och Strängnäs valkrets   andrakammarledamot
# 1      Västra Götalands läns västra valkrets  förstakammarledamot
# 2                      Torna härads valkrets   andrakammarledamot
# 3                    Värmlands läns valkrets  förstakammarledamot
# 4                Kristianstads läns valkrets  förstakammarledamot
# ...                                      ...                  ...
# 13219               Stockholms läns valkrets              ledamot
# 13220                  Uppsala läns valkrets              ledamot
# 13221                Jämtlands läns valkrets              ledamot
# 13222                                    NaN              ledamot
# 13223                                    NaN              ledamot
#
#                        party
# 0                        NaN
# 1                        NaN
# 2      ministeriella partiet
# 3                        NaN
# 4                        NaN
# ...                      ...
# 13219                    NaN
# 13220                    NaN
# 13221                    NaN
# 13222                    NaN
# 13223                    NaN
#
# [13224 rows x 6 columns]
#                       person_id       start         end  \
# 2      i-Ddmtm1uG9esPH37c8XjUXZ        1867        1867
# 30      i-txhZTbUuKZkkaU5vYzZgH        1867        1868
# 74     i-6crgYxGFmn73aep9gWDLzZ        1867        1869
# 80     i-YFzzFKh2NjM54cFjad2qWQ        1867        1869
# 92     i-6P9WGen454XYD7xwVEV6JX        1867        1869
# ...                         ...         ...         ...
# 12865  i-PjQgLPLrkyDV2oYQfyuWq2  2022-09-26  2024-04-17
# 12866  i-XKBEUKbavmqFvdi75cDrts  2023-06-01  2024-04-21
# 12867  i-15XKZT3hRjksEvtHa8x3vk  2023-08-28  2024-04-30
# 12868  i-SKsrTm4gWQzab9KkjqBLKS  2023-10-16  2024-05-01
# 12869  i-TP1gKqVgWU4EH5fBdPaTQB  2024-04-18  2024-05-31
#
#                                 district                role  \
# 2                  Torna härads valkrets  andrakammarledamot
# 30                                   NaN  andrakammarledamot
# 74         Ovansiljans domsagas valkrets  andrakammarledamot
# 80              Göteborgs stads valkrets  andrakammarledamot
# 92     Jämtlands norra domsagas valkrets  andrakammarledamot
# ...                                  ...                 ...
# 12865           Stockholms läns valkrets             ledamot
# 12866           Stockholms läns valkrets             ledamot
# 12867              Uppsala läns valkrets             ledamot
# 12868            Jämtlands läns valkrets             ledamot
# 12869           Stockholms läns valkrets             ledamot
#
#                           party
# 2         ministeriella partiet
# 30        ministeriella partiet
# 74        ministeriella partiet
# 80        ministeriella partiet
# 92        ministeriella partiet
# ...                         ...
# 12865              Miljöpartiet
# 12866  Moderata samlingspartiet
# 12867        Socialdemokraterna
# 12868        Socialdemokraterna
# 12869              Miljöpartiet
#
# [7929 rows x 6 columns]

# %%
df
# Out:
#                       person_id      start        end  \
# 28354  i-122QwSSpyGJQiTJjmrUJCM 1992-03-17 1992-05-31
# 28355  i-122QwSSpyGJQiTJjmrUJCM 1992-03-17 1992-05-31
# 28431  i-122QwSSpyGJQiTJjmrUJCM 1992-11-26 1992-12-31
# 28432  i-122QwSSpyGJQiTJjmrUJCM 1992-11-26 1992-12-31
# 28444  i-122QwSSpyGJQiTJjmrUJCM 1993-01-11 1993-01-25
# ...                         ...        ...        ...
# 26696   i-zC3ZtMw7pF7WxkXwbLkKZ 1986-01-10 1988-10-03
# 26994   i-zC3ZtMw7pF7WxkXwbLkKZ 1988-10-03 1989-01-10
# 26995   i-zC3ZtMw7pF7WxkXwbLkKZ 1988-10-03 1989-01-10
# 26996   i-zC3ZtMw7pF7WxkXwbLkKZ 1988-10-03 1989-01-10
# 26997   i-zC3ZtMw7pF7WxkXwbLkKZ 1988-10-03 1989-01-10
#
#                        district     role                     party  \
# 28354                       NaN  ledamot        Socialdemokraterna
# 28355                       NaN  ledamot        Socialdemokraterna
# 28431                       NaN  ledamot        Socialdemokraterna
# 28432                       NaN  ledamot        Socialdemokraterna
# 28444                       NaN  ledamot        Socialdemokraterna
# ...                         ...      ...                       ...
# 26696                       NaN  ledamot  Moderata samlingspartiet
# 26994  Stockholms läns valkrets  ledamot  Moderata samlingspartiet
# 26995  Stockholms läns valkrets  ledamot  Moderata samlingspartiet
# 26996  Stockholms läns valkrets  ledamot  Moderata samlingspartiet
# 26997  Stockholms läns valkrets  ledamot  Moderata samlingspartiet
#
#                      source chamber government        born dead gender  \
# 28354  member_of_parliament       0        NaN  1952-09-22  NaN    man
# 28355  member_of_parliament       0        NaN  1952-09-22  NaN    man
# 28431  member_of_parliament       0        NaN  1952-09-22  NaN    man
# 28432  member_of_parliament       0        NaN  1952-09-22  NaN    man
# 28444  member_of_parliament       0        NaN  1952-09-22  NaN    man
# ...                     ...     ...        ...         ...  ...    ...
# 26696  member_of_parliament       0        NaN  1943-10-19  NaN  woman
# 26994  member_of_parliament       0        NaN  1943-10-19  NaN  woman
# 26995  member_of_parliament       0        NaN  1943-10-19  NaN  woman
# 26996  member_of_parliament       0        NaN  1943-10-19  NaN  woman
# 26997  member_of_parliament       0        NaN  1943-10-19  NaN  woman
#
#         riksdagen_id    location                      name primary_name  \
# 28354  0573136138218   Västervik         krister örnfjäder         True
# 28355  0573136138218   Västervik                 örnfjäder        False
# 28431  0573136138218   Västervik         krister örnfjäder         True
# 28432  0573136138218   Västervik                 örnfjäder        False
# 28444  0573136138218   Västervik         krister örnfjäder         True
# ...              ...         ...                       ...          ...
# 26696  0233182252702  Åkersberga                 sundström        False
# 26994  0233182252702  Åkersberga                   gardner        False
# 26995  0233182252702  Åkersberga  ingela gardner sundström         True
# 26996  0233182252702  Åkersberga  kerstin ingela sundström        False
# 26997  0233182252702  Åkersberga                 sundström        False
#
#       party_abbrev twitter
# 28354            S     NaN
# 28355            S     NaN
# 28431            S     NaN
# 28432            S     NaN
# 28444            S     NaN
# ...            ...     ...
# 26696          NaN     NaN
# 26994          NaN     NaN
# 26995          NaN     NaN
# 26996          NaN     NaN
# 26997          NaN     NaN
#
# [46249 rows x 18 columns]

# %%
df["role"].unique()
# Out:
# array(['ledamot', 'lantförsvarsminister', 'försvarsminister',
#        'utrikesminister', 'finansmarknadsminister', 'inrikesminister',
#        'näringsminister', 'andre vice talman', 'förste vice talman',
#        'vice talman', 'eu-minister', 'utrikeshandelsminister',
#        'landsbygdsminister', 'jordbruksminister', 'civilminister',
#        'konsultativt statsråd', 'ecklesiastikminister', 'socialminister',
#        'kommunminister', 'kommunikationsminister',
#        'minister för nordiskt samarbete',
#        'statsministerns ställföretädare', 'handelsminister',
#        'justitieminister', 'sjöförsvarsminister', 'finansminister',
#        'biträdande finansminister', 'budgetminister', 'ekonomiminister',
#        'socialförsäkringsminister', 'sjukvårdsminister',
#        'samfundsminister', 'biståndsminister', 'migrationsminister',
#        'invandrarminister', 'jämställdhetsminister', 'skolminister',
#        'statsminister', 'infrastrukturminister',
#        'biträdande jordbruksminister', 'folkhushållningsminister',
#        'energiminister', 'talman', 'bostadsminister', 'miljöminister',
#        'idrottsminister', 'skatteminister', 'löneminister',
#        'arbetsmarknadsminister', 'utrikesstatsminister',
#        'biträdande bostadsminister', 'kulturminister',
#        'biträdande justitieminister', 'minister för civilt försvar',
#        'folkhälsominister', 'samordningsminister', 'arbetsrättsminister',
#        'integrationsminister', 'konsumentminister', 'ungdomsminister',
#        'klimatminister', 'utbildningsminister', 'digitaliseringsminister',
#        'högskoleminister', 'vice statsminister', 'demokratiminister',
#        'biträdande arbetsmarknadsminister', 'straffrättsminister',
#        'biträdande socialminister', 'biträdande utbildningsminister',
#        'minister för högre utbildning och forskning', 'planminister',
#        'barnminister', 'biträdande industriminister', 'äldreminister',
#        'socialtjänstminister'], dtype=object)

# %% [markdown]
# Generate a new variable called role cathegory to easily determine, if the person is a minister, MP or other.

# %%
minister_roles = [
    'lantförsvarsminister', 'försvarsminister', 'utrikesminister',
    'finansmarknadsminister', 'inrikesminister', 'näringsminister',
    'eu-minister', 'utrikeshandelsminister', 'landsbygdsminister',
    'jordbruksminister', 'civilminister', 'socialminister',
    'kommunminister', 'kommunikationsminister', 'minister för nordiskt samarbete',
    'handelsminister', 'justitieminister', 'sjöförsvarsminister',
    'finansminister', 'biträdande finansminister', 'budgetminister',
    'ekonomiminister', 'socialförsäkringsminister', 'sjukvårdsminister',
    'samfundsminister', 'biståndsminister', 'migrationsminister',
    'invandrarminister', 'jämställdhetsminister', 'skolminister',
    'statsminister', 'infrastrukturminister', 'biträdande jordbruksminister',
    'folkhushållningsminister', 'energiminister', 'bostadsminister',
    'miljöminister', 'idrottsminister', 'skatteminister', 'löneminister',
    'arbetsmarknadsminister', 'utrikesstatsminister', 'biträdande bostadsminister',
    'kulturminister', 'biträdande justitieminister', 'minister för civilt försvar',
    'folkhälsominister', 'samordningsminister', 'arbetsrättsminister',
    'integrationsminister', 'konsumentminister', 'ungdomsminister',
    'klimatminister', 'utbildningsminister', 'digitaliseringsminister',
    'högskoleminister', 'vice statsminister', 'demokratiminister',
    'biträdande arbetsmarknadsminister', 'straffrättsminister',
    'biträdande socialminister', 'biträdande utbildningsminister',
    'minister för högre utbildning och forskning', 'planminister',
    'barnminister', 'biträdande industriminister', 'äldreminister',
    'socialtjänstminister'
]

mp_roles = ['ledamot']

other_non_questioning_roles = [
    'talman', 'förste vice talman', 'andre vice talman', 'vice talman',
    'konsultativt statsråd', 'statsministerns ställföretädare'
]

def categorize_role(role):
    if role in minister_roles:
        return 'minister'
    elif role in mp_roles:
        return 'mp'
    elif role in other_non_questioning_roles:
        return 'other'
    else:
        return 'unknown'

# %% [markdown]
# Choose the necessary columns and clean the dataset.

# %%
new_df = df[["person_id", "role"]].copy()
new_df["role_category"] = new_df["role"].apply(categorize_role)

# %%
new_df
# Out:
#                       person_id     role role_category
# 28354  i-122QwSSpyGJQiTJjmrUJCM  ledamot            mp
# 28355  i-122QwSSpyGJQiTJjmrUJCM  ledamot            mp
# 28431  i-122QwSSpyGJQiTJjmrUJCM  ledamot            mp
# 28432  i-122QwSSpyGJQiTJjmrUJCM  ledamot            mp
# 28444  i-122QwSSpyGJQiTJjmrUJCM  ledamot            mp
# ...                         ...      ...           ...
# 26696   i-zC3ZtMw7pF7WxkXwbLkKZ  ledamot            mp
# 26994   i-zC3ZtMw7pF7WxkXwbLkKZ  ledamot            mp
# 26995   i-zC3ZtMw7pF7WxkXwbLkKZ  ledamot            mp
# 26996   i-zC3ZtMw7pF7WxkXwbLkKZ  ledamot            mp
# 26997   i-zC3ZtMw7pF7WxkXwbLkKZ  ledamot            mp
#
# [46249 rows x 3 columns]

# %% [markdown]
# # 1. Implementation test

# %% [markdown]
# Code to scan unique sections of one file

# %%
from lxml import etree
from pyriksdagen.utils import corpus_iterator

# %%
protocols = list(corpus_iterator(document_type="prot", corpus_root="data/", start=1867, end=2023))
protocol_in_question = protocols[12]
parser = etree.XMLParser(encoding='utf-8')
root = etree.parse(protocol_in_question, parser).getroot()

# %%
NS = {"tei": "http://www.tei-c.org/ns/1.0"}

# %%
divs = root.findall(".//tei:text/tei:body//tei:div", namespaces=NS)
section_types = {div.attrib.get("type") for div in divs if div.attrib.get("type")}

# %%
print("Unique <div type=...> section types found:")
for t in sorted(section_types):
    print(f"- {t}")
# Out:
# Unique <div type=...> section types found:
# - commentSection
# - debateSection

# %% [markdown]
# Code to scan unique sections of all the files:

# %%
from lxml import etree
from pyriksdagen.utils import corpus_iterator

def extract_all_div_types(corpus_root="data/", start=1867, end=2023):
    NS = {"tei": "http://www.tei-c.org/ns/1.0"}
    protocols = corpus_iterator(document_type="prot", corpus_root=corpus_root, start=start, end=end)
    
    all_section_types = set()

    for i, protocol_path in enumerate(protocols):
        try:
            parser = etree.XMLParser(encoding='utf-8')
            root = etree.parse(protocol_path, parser).getroot()
            divs = root.findall(".//tei:text/tei:body//tei:div", namespaces=NS)
            section_types = {div.attrib.get("type") for div in divs if div.attrib.get("type")}
            all_section_types.update(section_types)
        except Exception as e:
            print(f"Error parsing {protocol_path}: {e}")
            continue
        
        if i % 500 == 0:
            print(f"Processed {i} files...")

    return sorted(all_section_types)

# %%
extract_all_div_types() # Files to process: 17938
# Out:
# Processed 0 files...
# Processed 500 files...
# Processed 1000 files...
# Processed 1500 files...
# Processed 2000 files...
# Processed 2500 files...
# Processed 3000 files...
# Processed 3500 files...
# Processed 4000 files...
# Processed 4500 files...
# Processed 5000 files...
# Processed 5500 files...
# Processed 6000 files...
# Processed 6500 files...
# Processed 7000 files...
# Processed 7500 files...
# Processed 8000 files...
# Processed 8500 files...
# Processed 9000 files...
# Processed 9500 files...
# Processed 10000 files...
# Processed 10500 files...
# Processed 11000 files...
# Processed 11500 files...
# Processed 12000 files...
# Processed 12500 files...
# Processed 13000 files...
# Processed 13500 files...
# Processed 14000 files...
# Processed 14500 files...
# Processed 15000 files...
# Processed 15500 files...
# Processed 16000 files...
# Processed 16500 files...
# Processed 17000 files...
# Processed 17500 files...
# ['commentSection', 'debateSection']

# %% [markdown]
# Seems that the main sections are comment and debate sections. Inspecting some example files, we can note that the commentSection is a short overview of the protocol contents, and debateSection the actual part where the debates and Q&A sessions are held

# %%
utterances = root.findall(".//tei:u", namespaces=NS)

print("\nUtterances with IDs and links:")
for u in utterances:
    u_id = u.attrib.get("xml:id") or u.attrib.get("{http://www.w3.org/XML/1998/namespace}id")
    who = u.attrib.get("who")
    prev = u.attrib.get("prev")
    next_ = u.attrib.get("next")
    print(f"ID: {u_id}, who: {who}, prev: {prev}, next: {next_}")
# Out:
# Utterances with IDs and links:
# ID: i-HoQq5gaYJ5z2XsaZqhAUe8, who: unknown, prev: None, next: None
# ID: i-e1bac02d35b800f5-0, who: unknown, prev: None, next: None
# ID: i-e1bac02d35b800f5-2, who: i-HP26Ex6XfZD2gozC8P6pdm, prev: None, next: i-e1bac02d35b800f5-3
# ID: i-e1bac02d35b800f5-3, who: i-HP26Ex6XfZD2gozC8P6pdm, prev: i-e1bac02d35b800f5-2, next: i-e1bac02d35b800f5-4
# ID: i-e1bac02d35b800f5-4, who: i-HP26Ex6XfZD2gozC8P6pdm, prev: i-e1bac02d35b800f5-3, next: i-e1bac02d35b800f5-5
# ID: i-e1bac02d35b800f5-5, who: i-HP26Ex6XfZD2gozC8P6pdm, prev: i-e1bac02d35b800f5-4, next: i-e1bac02d35b800f5-6
# ID: i-e1bac02d35b800f5-6, who: i-HP26Ex6XfZD2gozC8P6pdm, prev: i-e1bac02d35b800f5-5, next: i-e1bac02d35b800f5-7
# ID: i-e1bac02d35b800f5-7, who: i-HP26Ex6XfZD2gozC8P6pdm, prev: i-e1bac02d35b800f5-6, next: None
# ID: i-e1bac02d35b800f5-8, who: i-F8qdE2eedz12PwFanq3ahv, prev: None, next: i-e1bac02d35b800f5-9
# ID: i-e1bac02d35b800f5-9, who: i-F8qdE2eedz12PwFanq3ahv, prev: i-e1bac02d35b800f5-8, next: i-e1bac02d35b800f5-11
# ID: i-e1bac02d35b800f5-11, who: i-F8qdE2eedz12PwFanq3ahv, prev: i-e1bac02d35b800f5-9, next: i-e1bac02d35b800f5-12
# ID: i-e1bac02d35b800f5-12, who: i-F8qdE2eedz12PwFanq3ahv, prev: i-e1bac02d35b800f5-11, next: i-e1bac02d35b800f5-13
# ID: i-e1bac02d35b800f5-13, who: i-F8qdE2eedz12PwFanq3ahv, prev: i-e1bac02d35b800f5-12, next: i-e1bac02d35b800f5-14
# ID: i-e1bac02d35b800f5-14, who: i-F8qdE2eedz12PwFanq3ahv, prev: i-e1bac02d35b800f5-13, next: i-e1bac02d35b800f5-15
# ID: i-e1bac02d35b800f5-15, who: i-F8qdE2eedz12PwFanq3ahv, prev: i-e1bac02d35b800f5-14, next: i-e1bac02d35b800f5-16
# ID: i-e1bac02d35b800f5-16, who: i-F8qdE2eedz12PwFanq3ahv, prev: i-e1bac02d35b800f5-15, next: None
# ID: i-e1bac02d35b800f5-17, who: i-HP26Ex6XfZD2gozC8P6pdm, prev: None, next: i-e1bac02d35b800f5-18
# ID: i-e1bac02d35b800f5-18, who: i-HP26Ex6XfZD2gozC8P6pdm, prev: i-e1bac02d35b800f5-17, next: i-e1bac02d35b800f5-19
# ID: i-e1bac02d35b800f5-19, who: i-HP26Ex6XfZD2gozC8P6pdm, prev: i-e1bac02d35b800f5-18, next: i-e1bac02d35b800f5-20
# ID: i-e1bac02d35b800f5-20, who: i-HP26Ex6XfZD2gozC8P6pdm, prev: i-e1bac02d35b800f5-19, next: i-e1bac02d35b800f5-21
# ID: i-e1bac02d35b800f5-21, who: i-HP26Ex6XfZD2gozC8P6pdm, prev: i-e1bac02d35b800f5-20, next: i-e1bac02d35b800f5-22
# ID: i-e1bac02d35b800f5-22, who: i-HP26Ex6XfZD2gozC8P6pdm, prev: i-e1bac02d35b800f5-21, next: i-e1bac02d35b800f5-23
# ID: i-e1bac02d35b800f5-23, who: i-HP26Ex6XfZD2gozC8P6pdm, prev: i-e1bac02d35b800f5-22, next: None
# ID: i-e1bac02d35b800f5-24, who: i-F8qdE2eedz12PwFanq3ahv, prev: None, next: i-e1bac02d35b800f5-25
# ID: i-e1bac02d35b800f5-25, who: i-F8qdE2eedz12PwFanq3ahv, prev: i-e1bac02d35b800f5-24, next: i-e1bac02d35b800f5-26
# ID: i-e1bac02d35b800f5-26, who: i-F8qdE2eedz12PwFanq3ahv, prev: i-e1bac02d35b800f5-25, next: i-e1bac02d35b800f5-27
# ID: i-e1bac02d35b800f5-27, who: i-F8qdE2eedz12PwFanq3ahv, prev: i-e1bac02d35b800f5-26, next: None
# ID: i-e1bac02d35b800f5-28, who: i-HP26Ex6XfZD2gozC8P6pdm, prev: None, next: i-e1bac02d35b800f5-29
# ID: i-e1bac02d35b800f5-29, who: i-HP26Ex6XfZD2gozC8P6pdm, prev: i-e1bac02d35b800f5-28, next: i-e1bac02d35b800f5-30
# ID: i-e1bac02d35b800f5-30, who: i-HP26Ex6XfZD2gozC8P6pdm, prev: i-e1bac02d35b800f5-29, next: i-e1bac02d35b800f5-31
# ID: i-e1bac02d35b800f5-31, who: i-HP26Ex6XfZD2gozC8P6pdm, prev: i-e1bac02d35b800f5-30, next: i-e1bac02d35b800f5-32
# ID: i-e1bac02d35b800f5-32, who: i-HP26Ex6XfZD2gozC8P6pdm, prev: i-e1bac02d35b800f5-31, next: None
# ID: i-e1bac02d35b800f5-33, who: i-F8qdE2eedz12PwFanq3ahv, prev: None, next: i-e1bac02d35b800f5-34
# ID: i-e1bac02d35b800f5-34, who: i-F8qdE2eedz12PwFanq3ahv, prev: i-e1bac02d35b800f5-33, next: i-e1bac02d35b800f5-35
# ID: i-e1bac02d35b800f5-35, who: i-F8qdE2eedz12PwFanq3ahv, prev: i-e1bac02d35b800f5-34, next: i-e1bac02d35b800f5-36
# ID: i-e1bac02d35b800f5-36, who: i-F8qdE2eedz12PwFanq3ahv, prev: i-e1bac02d35b800f5-35, next: None
# ID: i-e1bac02d35b800f5-37, who: i-HP26Ex6XfZD2gozC8P6pdm, prev: None, next: i-e1bac02d35b800f5-38
# ID: i-e1bac02d35b800f5-38, who: i-HP26Ex6XfZD2gozC8P6pdm, prev: i-e1bac02d35b800f5-37, next: i-e1bac02d35b800f5-39
# ID: i-e1bac02d35b800f5-39, who: i-HP26Ex6XfZD2gozC8P6pdm, prev: i-e1bac02d35b800f5-38, next: i-e1bac02d35b800f5-40
# ID: i-e1bac02d35b800f5-40, who: i-HP26Ex6XfZD2gozC8P6pdm, prev: i-e1bac02d35b800f5-39, next: i-e1bac02d35b800f5-41
# ID: i-e1bac02d35b800f5-41, who: i-HP26Ex6XfZD2gozC8P6pdm, prev: i-e1bac02d35b800f5-40, next: i-e1bac02d35b800f5-42
# ID: i-e1bac02d35b800f5-42, who: i-HP26Ex6XfZD2gozC8P6pdm, prev: i-e1bac02d35b800f5-41, next: i-e1bac02d35b800f5-43
# ID: i-e1bac02d35b800f5-43, who: i-HP26Ex6XfZD2gozC8P6pdm, prev: i-e1bac02d35b800f5-42, next: None
# ID: i-e1bac02d35b800f5-44, who: i-XXHxxQRuSjGXVxaVhcXaFk, prev: None, next: i-e1bac02d35b800f5-45
# ID: i-e1bac02d35b800f5-45, who: i-XXHxxQRuSjGXVxaVhcXaFk, prev: i-e1bac02d35b800f5-44, next: i-e1bac02d35b800f5-46
# ID: i-e1bac02d35b800f5-46, who: i-XXHxxQRuSjGXVxaVhcXaFk, prev: i-e1bac02d35b800f5-45, next: i-e1bac02d35b800f5-47
# ID: i-e1bac02d35b800f5-47, who: i-XXHxxQRuSjGXVxaVhcXaFk, prev: i-e1bac02d35b800f5-46, next: i-e1bac02d35b800f5-48
# ID: i-e1bac02d35b800f5-48, who: i-XXHxxQRuSjGXVxaVhcXaFk, prev: i-e1bac02d35b800f5-47, next: i-e1bac02d35b800f5-49
# ID: i-e1bac02d35b800f5-49, who: i-XXHxxQRuSjGXVxaVhcXaFk, prev: i-e1bac02d35b800f5-48, next: i-e1bac02d35b800f5-50
# ID: i-e1bac02d35b800f5-50, who: i-XXHxxQRuSjGXVxaVhcXaFk, prev: i-e1bac02d35b800f5-49, next: i-e1bac02d35b800f5-51
# ID: i-e1bac02d35b800f5-51, who: i-XXHxxQRuSjGXVxaVhcXaFk, prev: i-e1bac02d35b800f5-50, next: i-e1bac02d35b800f5-52
# ID: i-e1bac02d35b800f5-52, who: i-XXHxxQRuSjGXVxaVhcXaFk, prev: i-e1bac02d35b800f5-51, next: i-e1bac02d35b800f5-53
# ID: i-e1bac02d35b800f5-53, who: i-XXHxxQRuSjGXVxaVhcXaFk, prev: i-e1bac02d35b800f5-52, next: i-e1bac02d35b800f5-54
# ID: i-e1bac02d35b800f5-54, who: i-XXHxxQRuSjGXVxaVhcXaFk, prev: i-e1bac02d35b800f5-53, next: i-e1bac02d35b800f5-55
# ID: i-e1bac02d35b800f5-55, who: i-XXHxxQRuSjGXVxaVhcXaFk, prev: i-e1bac02d35b800f5-54, next: i-e1bac02d35b800f5-56
# ID: i-e1bac02d35b800f5-56, who: i-XXHxxQRuSjGXVxaVhcXaFk, prev: i-e1bac02d35b800f5-55, next: None
# ID: i-e1bac02d35b800f5-57, who: i-HP26Ex6XfZD2gozC8P6pdm, prev: None, next: i-e1bac02d35b800f5-58
# ID: i-e1bac02d35b800f5-58, who: i-HP26Ex6XfZD2gozC8P6pdm, prev: i-e1bac02d35b800f5-57, next: i-e1bac02d35b800f5-59
# ID: i-e1bac02d35b800f5-59, who: i-HP26Ex6XfZD2gozC8P6pdm, prev: i-e1bac02d35b800f5-58, next: i-e1bac02d35b800f5-60
# ID: i-e1bac02d35b800f5-60, who: i-HP26Ex6XfZD2gozC8P6pdm, prev: i-e1bac02d35b800f5-59, next: i-e1bac02d35b800f5-61
# ID: i-e1bac02d35b800f5-61, who: i-HP26Ex6XfZD2gozC8P6pdm, prev: i-e1bac02d35b800f5-60, next: i-e1bac02d35b800f5-62
# ID: i-e1bac02d35b800f5-62, who: i-HP26Ex6XfZD2gozC8P6pdm, prev: i-e1bac02d35b800f5-61, next: i-e1bac02d35b800f5-63
# ID: i-e1bac02d35b800f5-63, who: i-HP26Ex6XfZD2gozC8P6pdm, prev: i-e1bac02d35b800f5-62, next: i-e1bac02d35b800f5-64
# ID: i-e1bac02d35b800f5-64, who: i-HP26Ex6XfZD2gozC8P6pdm, prev: i-e1bac02d35b800f5-63, next: i-e1bac02d35b800f5-65
# ID: i-e1bac02d35b800f5-65, who: i-HP26Ex6XfZD2gozC8P6pdm, prev: i-e1bac02d35b800f5-64, next: i-e1bac02d35b800f5-66
# ID: i-e1bac02d35b800f5-66, who: i-HP26Ex6XfZD2gozC8P6pdm, prev: i-e1bac02d35b800f5-65, next: i-e1bac02d35b800f5-67
# ID: i-e1bac02d35b800f5-67, who: i-HP26Ex6XfZD2gozC8P6pdm, prev: i-e1bac02d35b800f5-66, next: i-e1bac02d35b800f5-68
# ID: i-e1bac02d35b800f5-68, who: i-HP26Ex6XfZD2gozC8P6pdm, prev: i-e1bac02d35b800f5-67, next: i-e1bac02d35b800f5-69
# ID: i-e1bac02d35b800f5-69, who: i-HP26Ex6XfZD2gozC8P6pdm, prev: i-e1bac02d35b800f5-68, next: None
# ID: i-e1bac02d35b800f5-70, who: i-XXHxxQRuSjGXVxaVhcXaFk, prev: None, next: i-e1bac02d35b800f5-71
# ID: i-e1bac02d35b800f5-71, who: i-XXHxxQRuSjGXVxaVhcXaFk, prev: i-e1bac02d35b800f5-70, next: i-e1bac02d35b800f5-72
# ID: i-e1bac02d35b800f5-72, who: i-XXHxxQRuSjGXVxaVhcXaFk, prev: i-e1bac02d35b800f5-71, next: i-e1bac02d35b800f5-73
# ID: i-e1bac02d35b800f5-73, who: i-XXHxxQRuSjGXVxaVhcXaFk, prev: i-e1bac02d35b800f5-72, next: i-e1bac02d35b800f5-74
# ID: i-e1bac02d35b800f5-74, who: i-XXHxxQRuSjGXVxaVhcXaFk, prev: i-e1bac02d35b800f5-73, next: i-e1bac02d35b800f5-75
# ID: i-e1bac02d35b800f5-75, who: i-XXHxxQRuSjGXVxaVhcXaFk, prev: i-e1bac02d35b800f5-74, next: i-e1bac02d35b800f5-76
# ID: i-e1bac02d35b800f5-76, who: i-XXHxxQRuSjGXVxaVhcXaFk, prev: i-e1bac02d35b800f5-75, next: i-e1bac02d35b800f5-77
# ID: i-e1bac02d35b800f5-77, who: i-XXHxxQRuSjGXVxaVhcXaFk, prev: i-e1bac02d35b800f5-76, next: i-e1bac02d35b800f5-78
# ID: i-e1bac02d35b800f5-78, who: i-XXHxxQRuSjGXVxaVhcXaFk, prev: i-e1bac02d35b800f5-77, next: None
# ID: i-e1bac02d35b800f5-79, who: i-HP26Ex6XfZD2gozC8P6pdm, prev: None, next: i-e1bac02d35b800f5-80
# ID: i-e1bac02d35b800f5-80, who: i-HP26Ex6XfZD2gozC8P6pdm, prev: i-e1bac02d35b800f5-79, next: i-e1bac02d35b800f5-81
# ID: i-e1bac02d35b800f5-81, who: i-HP26Ex6XfZD2gozC8P6pdm, prev: i-e1bac02d35b800f5-80, next: i-e1bac02d35b800f5-82
# ID: i-e1bac02d35b800f5-82, who: i-HP26Ex6XfZD2gozC8P6pdm, prev: i-e1bac02d35b800f5-81, next: None
# ID: i-e1bac02d35b800f5-83, who: i-XXHxxQRuSjGXVxaVhcXaFk, prev: None, next: i-e1bac02d35b800f5-84
# ID: i-e1bac02d35b800f5-84, who: i-XXHxxQRuSjGXVxaVhcXaFk, prev: i-e1bac02d35b800f5-83, next: None
# ID: i-e1bac02d35b800f5-85, who: i-sS6VZTVNkCN6AHvZNaaYb, prev: None, next: i-e1bac02d35b800f5-86
# ID: i-e1bac02d35b800f5-86, who: i-sS6VZTVNkCN6AHvZNaaYb, prev: i-e1bac02d35b800f5-85, next: i-e1bac02d35b800f5-87
# ID: i-e1bac02d35b800f5-87, who: i-sS6VZTVNkCN6AHvZNaaYb, prev: i-e1bac02d35b800f5-86, next: i-e1bac02d35b800f5-88
# ID: i-e1bac02d35b800f5-88, who: i-sS6VZTVNkCN6AHvZNaaYb, prev: i-e1bac02d35b800f5-87, next: i-e1bac02d35b800f5-89
# ID: i-e1bac02d35b800f5-89, who: i-sS6VZTVNkCN6AHvZNaaYb, prev: i-e1bac02d35b800f5-88, next: i-e1bac02d35b800f5-90
# ID: i-e1bac02d35b800f5-90, who: i-sS6VZTVNkCN6AHvZNaaYb, prev: i-e1bac02d35b800f5-89, next: i-e1bac02d35b800f5-91
# ID: i-e1bac02d35b800f5-91, who: i-sS6VZTVNkCN6AHvZNaaYb, prev: i-e1bac02d35b800f5-90, next: i-6BGaqNyUNFNsj56xvWXo5V
# ID: i-6BGaqNyUNFNsj56xvWXo5V, who: i-sS6VZTVNkCN6AHvZNaaYb, prev: i-e1bac02d35b800f5-91, next: i-e1bac02d35b800f5-92
# ID: i-e1bac02d35b800f5-92, who: i-sS6VZTVNkCN6AHvZNaaYb, prev: i-6BGaqNyUNFNsj56xvWXo5V, next: i-e1bac02d35b800f5-93
# ID: i-e1bac02d35b800f5-93, who: i-sS6VZTVNkCN6AHvZNaaYb, prev: i-e1bac02d35b800f5-92, next: i-e1bac02d35b800f5-94
# ID: i-e1bac02d35b800f5-94, who: i-sS6VZTVNkCN6AHvZNaaYb, prev: i-e1bac02d35b800f5-93, next: i-e1bac02d35b800f5-95
# ID: i-e1bac02d35b800f5-95, who: i-sS6VZTVNkCN6AHvZNaaYb, prev: i-e1bac02d35b800f5-94, next: i-e1bac02d35b800f5-96
# ID: i-e1bac02d35b800f5-96, who: i-sS6VZTVNkCN6AHvZNaaYb, prev: i-e1bac02d35b800f5-95, next: i-e1bac02d35b800f5-97
# ID: i-e1bac02d35b800f5-97, who: i-sS6VZTVNkCN6AHvZNaaYb, prev: i-e1bac02d35b800f5-96, next: None
# ID: i-e1bac02d35b800f5-98, who: i-J74sVAjCTSxzD8rbnxRRA, prev: None, next: i-e1bac02d35b800f5-99
# ID: i-e1bac02d35b800f5-99, who: i-J74sVAjCTSxzD8rbnxRRA, prev: i-e1bac02d35b800f5-98, next: i-e1bac02d35b800f5-100
# ID: i-e1bac02d35b800f5-100, who: i-J74sVAjCTSxzD8rbnxRRA, prev: i-e1bac02d35b800f5-99, next: i-e1bac02d35b800f5-101
# ID: i-e1bac02d35b800f5-101, who: i-J74sVAjCTSxzD8rbnxRRA, prev: i-e1bac02d35b800f5-100, next: i-e1bac02d35b800f5-102
# ID: i-e1bac02d35b800f5-102, who: i-J74sVAjCTSxzD8rbnxRRA, prev: i-e1bac02d35b800f5-101, next: i-e1bac02d35b800f5-103
# ID: i-e1bac02d35b800f5-103, who: i-J74sVAjCTSxzD8rbnxRRA, prev: i-e1bac02d35b800f5-102, next: i-e1bac02d35b800f5-104
# ID: i-e1bac02d35b800f5-104, who: i-J74sVAjCTSxzD8rbnxRRA, prev: i-e1bac02d35b800f5-103, next: i-e1bac02d35b800f5-105
# ID: i-e1bac02d35b800f5-105, who: i-J74sVAjCTSxzD8rbnxRRA, prev: i-e1bac02d35b800f5-104, next: i-e1bac02d35b800f5-106
# ID: i-e1bac02d35b800f5-106, who: i-J74sVAjCTSxzD8rbnxRRA, prev: i-e1bac02d35b800f5-105, next: None
# ID: i-e1bac02d35b800f5-107, who: i-sS6VZTVNkCN6AHvZNaaYb, prev: None, next: i-e1bac02d35b800f5-108
# ID: i-e1bac02d35b800f5-108, who: i-sS6VZTVNkCN6AHvZNaaYb, prev: i-e1bac02d35b800f5-107, next: i-e1bac02d35b800f5-109
# ID: i-e1bac02d35b800f5-109, who: i-sS6VZTVNkCN6AHvZNaaYb, prev: i-e1bac02d35b800f5-108, next: i-e1bac02d35b800f5-110
# ID: i-e1bac02d35b800f5-110, who: i-sS6VZTVNkCN6AHvZNaaYb, prev: i-e1bac02d35b800f5-109, next: i-e1bac02d35b800f5-112
# ID: i-e1bac02d35b800f5-112, who: i-sS6VZTVNkCN6AHvZNaaYb, prev: i-e1bac02d35b800f5-110, next: i-e1bac02d35b800f5-113
# ID: i-e1bac02d35b800f5-113, who: i-sS6VZTVNkCN6AHvZNaaYb, prev: i-e1bac02d35b800f5-112, next: i-e1bac02d35b800f5-114
# ID: i-e1bac02d35b800f5-114, who: i-sS6VZTVNkCN6AHvZNaaYb, prev: i-e1bac02d35b800f5-113, next: i-e1bac02d35b800f5-115
# ID: i-e1bac02d35b800f5-115, who: i-sS6VZTVNkCN6AHvZNaaYb, prev: i-e1bac02d35b800f5-114, next: i-e1bac02d35b800f5-116
# ID: i-e1bac02d35b800f5-116, who: i-sS6VZTVNkCN6AHvZNaaYb, prev: i-e1bac02d35b800f5-115, next: i-e1bac02d35b800f5-117
# ID: i-e1bac02d35b800f5-117, who: i-sS6VZTVNkCN6AHvZNaaYb, prev: i-e1bac02d35b800f5-116, next: i-e1bac02d35b800f5-118
# ID: i-e1bac02d35b800f5-118, who: i-sS6VZTVNkCN6AHvZNaaYb, prev: i-e1bac02d35b800f5-117, next: None
# ID: i-e1bac02d35b800f5-119, who: i-J74sVAjCTSxzD8rbnxRRA, prev: None, next: i-e1bac02d35b800f5-120
# ID: i-e1bac02d35b800f5-120, who: i-J74sVAjCTSxzD8rbnxRRA, prev: i-e1bac02d35b800f5-119, next: i-e1bac02d35b800f5-121
# ID: i-e1bac02d35b800f5-121, who: i-J74sVAjCTSxzD8rbnxRRA, prev: i-e1bac02d35b800f5-120, next: i-e1bac02d35b800f5-122
# ID: i-e1bac02d35b800f5-122, who: i-J74sVAjCTSxzD8rbnxRRA, prev: i-e1bac02d35b800f5-121, next: i-e1bac02d35b800f5-123
# ID: i-e1bac02d35b800f5-123, who: i-J74sVAjCTSxzD8rbnxRRA, prev: i-e1bac02d35b800f5-122, next: i-e1bac02d35b800f5-124
# ID: i-e1bac02d35b800f5-124, who: i-J74sVAjCTSxzD8rbnxRRA, prev: i-e1bac02d35b800f5-123, next: i-e1bac02d35b800f5-125
# ID: i-e1bac02d35b800f5-125, who: i-J74sVAjCTSxzD8rbnxRRA, prev: i-e1bac02d35b800f5-124, next: i-e1bac02d35b800f5-126
# ID: i-e1bac02d35b800f5-126, who: i-J74sVAjCTSxzD8rbnxRRA, prev: i-e1bac02d35b800f5-125, next: i-e1bac02d35b800f5-127
# ID: i-e1bac02d35b800f5-127, who: i-J74sVAjCTSxzD8rbnxRRA, prev: i-e1bac02d35b800f5-126, next: None
# ID: i-e1bac02d35b800f5-128, who: i-sS6VZTVNkCN6AHvZNaaYb, prev: None, next: i-e1bac02d35b800f5-129
# ID: i-e1bac02d35b800f5-129, who: i-sS6VZTVNkCN6AHvZNaaYb, prev: i-e1bac02d35b800f5-128, next: i-e1bac02d35b800f5-130
# ID: i-e1bac02d35b800f5-130, who: i-sS6VZTVNkCN6AHvZNaaYb, prev: i-e1bac02d35b800f5-129, next: i-e1bac02d35b800f5-131
# ID: i-e1bac02d35b800f5-131, who: i-sS6VZTVNkCN6AHvZNaaYb, prev: i-e1bac02d35b800f5-130, next: i-e1bac02d35b800f5-132
# ID: i-e1bac02d35b800f5-132, who: i-sS6VZTVNkCN6AHvZNaaYb, prev: i-e1bac02d35b800f5-131, next: i-e1bac02d35b800f5-133
# ID: i-e1bac02d35b800f5-133, who: i-sS6VZTVNkCN6AHvZNaaYb, prev: i-e1bac02d35b800f5-132, next: i-e1bac02d35b800f5-134
# ID: i-e1bac02d35b800f5-134, who: i-sS6VZTVNkCN6AHvZNaaYb, prev: i-e1bac02d35b800f5-133, next: i-e1bac02d35b800f5-135
# ID: i-e1bac02d35b800f5-135, who: i-sS6VZTVNkCN6AHvZNaaYb, prev: i-e1bac02d35b800f5-134, next: i-e1bac02d35b800f5-136
# ID: i-e1bac02d35b800f5-136, who: i-sS6VZTVNkCN6AHvZNaaYb, prev: i-e1bac02d35b800f5-135, next: i-e1bac02d35b800f5-137
# ID: i-e1bac02d35b800f5-137, who: i-sS6VZTVNkCN6AHvZNaaYb, prev: i-e1bac02d35b800f5-136, next: i-e1bac02d35b800f5-138
# ID: i-e1bac02d35b800f5-138, who: i-sS6VZTVNkCN6AHvZNaaYb, prev: i-e1bac02d35b800f5-137, next: None
# ID: i-e1bac02d35b800f5-139, who: i-J74sVAjCTSxzD8rbnxRRA, prev: None, next: i-e1bac02d35b800f5-140
# ID: i-e1bac02d35b800f5-140, who: i-J74sVAjCTSxzD8rbnxRRA, prev: i-e1bac02d35b800f5-139, next: i-e1bac02d35b800f5-141
# ID: i-e1bac02d35b800f5-141, who: i-J74sVAjCTSxzD8rbnxRRA, prev: i-e1bac02d35b800f5-140, next: i-e1bac02d35b800f5-142
# ID: i-e1bac02d35b800f5-142, who: i-J74sVAjCTSxzD8rbnxRRA, prev: i-e1bac02d35b800f5-141, next: i-e1bac02d35b800f5-143
# ID: i-e1bac02d35b800f5-143, who: i-J74sVAjCTSxzD8rbnxRRA, prev: i-e1bac02d35b800f5-142, next: None
# ID: i-e1bac02d35b800f5-144, who: i-sS6VZTVNkCN6AHvZNaaYb, prev: None, next: i-e1bac02d35b800f5-145
# ID: i-e1bac02d35b800f5-145, who: i-sS6VZTVNkCN6AHvZNaaYb, prev: i-e1bac02d35b800f5-144, next: i-e1bac02d35b800f5-146
# ID: i-e1bac02d35b800f5-146, who: i-sS6VZTVNkCN6AHvZNaaYb, prev: i-e1bac02d35b800f5-145, next: None
# ID: i-Pbwb4W1qZnobjNYF8nqapC, who: unknown, prev: None, next: None

# %% [markdown]
# Example code for one protocol to test the parsing of speakers

# %%
protocols = list(corpus_iterator(document_type="prot", corpus_root="data/", start=1867, end=2023))
protocol_in_question = protocols[14823]
parser = etree.XMLParser(encoding='utf-8')
root = etree.parse(protocol_in_question, parser).getroot()

# %%
protocol_in_question
# Out:
# 'data/200001/prot-200001--011.xml'

# %% [markdown]
# for one file

# %%
def parse_utterances(root, new_df):
    "function that finds the roles of the speakers present in the file with their order of speeches"
    NS = {"tei": "http://www.tei-c.org/ns/1.0"}

    def get_role(who_id):
        role = new_df.loc[new_df["person_id"] == who_id, "role_category"]
        return role.values[0].lower() if not role.empty else "unknown"

    all_utterances = []

    for section in root.findall(".//tei:div[@type='debateSection']", namespaces=NS):
        utterances = section.findall(".//tei:u", namespaces=NS)
        for u in utterances:
            u_id = u.attrib.get("xml:id") or u.attrib.get("{http://www.w3.org/XML/1998/namespace}id")
            who = u.attrib.get("who")
            role = get_role(who)

            all_utterances.append({
                "id": u_id,
                "who": who,
                "role": role,
            })

        all_utterances.append({
            "id": None,
            "who": None,
            "role": "section_break",
        })

    return all_utterances

def label_utterances_exact(utterances):
    labeled = []

    for i, utt in enumerate(utterances):
        role = utt["role"]
        who = utt["who"]

        if role == "section_break":
            labeled.append({**utt, "label": None})
            continue

        label = "question/remark"

        if role == "minister":
            label = "answer"
        else:
            for j in range(i + 1, len(utterances)):
                next_utt = utterances[j]
                if next_utt["role"] == "section_break":
                    label = "answer"
                    break
                elif next_utt["role"] == "mp" and next_utt["who"] != who:
                    label = "answer"
                    break
                elif next_utt["role"] == "minister":
                    break
                else:
                    continue

        labeled.append({**utt, "label": label})

    return [u for u in labeled if u["role"] != "section_break"]

# %%
parsed = parse_utterances(root, new_df)
labeled = label_utterances_exact(parsed)

# %%
labeled
# Out:
# [{'id': 'i-e1bac02d35b800f5-2',
#   'who': 'i-HP26Ex6XfZD2gozC8P6pdm',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-3',
#   'who': 'i-HP26Ex6XfZD2gozC8P6pdm',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-4',
#   'who': 'i-HP26Ex6XfZD2gozC8P6pdm',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-5',
#   'who': 'i-HP26Ex6XfZD2gozC8P6pdm',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-6',
#   'who': 'i-HP26Ex6XfZD2gozC8P6pdm',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-7',
#   'who': 'i-HP26Ex6XfZD2gozC8P6pdm',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-8',
#   'who': 'i-F8qdE2eedz12PwFanq3ahv',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-9',
#   'who': 'i-F8qdE2eedz12PwFanq3ahv',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-11',
#   'who': 'i-F8qdE2eedz12PwFanq3ahv',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-12',
#   'who': 'i-F8qdE2eedz12PwFanq3ahv',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-13',
#   'who': 'i-F8qdE2eedz12PwFanq3ahv',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-14',
#   'who': 'i-F8qdE2eedz12PwFanq3ahv',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-15',
#   'who': 'i-F8qdE2eedz12PwFanq3ahv',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-16',
#   'who': 'i-F8qdE2eedz12PwFanq3ahv',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-17',
#   'who': 'i-HP26Ex6XfZD2gozC8P6pdm',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-18',
#   'who': 'i-HP26Ex6XfZD2gozC8P6pdm',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-19',
#   'who': 'i-HP26Ex6XfZD2gozC8P6pdm',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-20',
#   'who': 'i-HP26Ex6XfZD2gozC8P6pdm',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-21',
#   'who': 'i-HP26Ex6XfZD2gozC8P6pdm',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-22',
#   'who': 'i-HP26Ex6XfZD2gozC8P6pdm',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-23',
#   'who': 'i-HP26Ex6XfZD2gozC8P6pdm',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-24',
#   'who': 'i-F8qdE2eedz12PwFanq3ahv',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-25',
#   'who': 'i-F8qdE2eedz12PwFanq3ahv',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-26',
#   'who': 'i-F8qdE2eedz12PwFanq3ahv',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-27',
#   'who': 'i-F8qdE2eedz12PwFanq3ahv',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-28',
#   'who': 'i-HP26Ex6XfZD2gozC8P6pdm',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-29',
#   'who': 'i-HP26Ex6XfZD2gozC8P6pdm',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-30',
#   'who': 'i-HP26Ex6XfZD2gozC8P6pdm',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-31',
#   'who': 'i-HP26Ex6XfZD2gozC8P6pdm',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-32',
#   'who': 'i-HP26Ex6XfZD2gozC8P6pdm',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-33',
#   'who': 'i-F8qdE2eedz12PwFanq3ahv',
#   'role': 'mp',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-34',
#   'who': 'i-F8qdE2eedz12PwFanq3ahv',
#   'role': 'mp',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-35',
#   'who': 'i-F8qdE2eedz12PwFanq3ahv',
#   'role': 'mp',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-36',
#   'who': 'i-F8qdE2eedz12PwFanq3ahv',
#   'role': 'mp',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-37',
#   'who': 'i-HP26Ex6XfZD2gozC8P6pdm',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-38',
#   'who': 'i-HP26Ex6XfZD2gozC8P6pdm',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-39',
#   'who': 'i-HP26Ex6XfZD2gozC8P6pdm',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-40',
#   'who': 'i-HP26Ex6XfZD2gozC8P6pdm',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-41',
#   'who': 'i-HP26Ex6XfZD2gozC8P6pdm',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-42',
#   'who': 'i-HP26Ex6XfZD2gozC8P6pdm',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-43',
#   'who': 'i-HP26Ex6XfZD2gozC8P6pdm',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-44',
#   'who': 'i-XXHxxQRuSjGXVxaVhcXaFk',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-45',
#   'who': 'i-XXHxxQRuSjGXVxaVhcXaFk',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-46',
#   'who': 'i-XXHxxQRuSjGXVxaVhcXaFk',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-47',
#   'who': 'i-XXHxxQRuSjGXVxaVhcXaFk',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-48',
#   'who': 'i-XXHxxQRuSjGXVxaVhcXaFk',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-49',
#   'who': 'i-XXHxxQRuSjGXVxaVhcXaFk',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-50',
#   'who': 'i-XXHxxQRuSjGXVxaVhcXaFk',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-51',
#   'who': 'i-XXHxxQRuSjGXVxaVhcXaFk',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-52',
#   'who': 'i-XXHxxQRuSjGXVxaVhcXaFk',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-53',
#   'who': 'i-XXHxxQRuSjGXVxaVhcXaFk',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-54',
#   'who': 'i-XXHxxQRuSjGXVxaVhcXaFk',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-55',
#   'who': 'i-XXHxxQRuSjGXVxaVhcXaFk',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-56',
#   'who': 'i-XXHxxQRuSjGXVxaVhcXaFk',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-57',
#   'who': 'i-HP26Ex6XfZD2gozC8P6pdm',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-58',
#   'who': 'i-HP26Ex6XfZD2gozC8P6pdm',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-59',
#   'who': 'i-HP26Ex6XfZD2gozC8P6pdm',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-60',
#   'who': 'i-HP26Ex6XfZD2gozC8P6pdm',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-61',
#   'who': 'i-HP26Ex6XfZD2gozC8P6pdm',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-62',
#   'who': 'i-HP26Ex6XfZD2gozC8P6pdm',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-63',
#   'who': 'i-HP26Ex6XfZD2gozC8P6pdm',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-64',
#   'who': 'i-HP26Ex6XfZD2gozC8P6pdm',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-65',
#   'who': 'i-HP26Ex6XfZD2gozC8P6pdm',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-66',
#   'who': 'i-HP26Ex6XfZD2gozC8P6pdm',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-67',
#   'who': 'i-HP26Ex6XfZD2gozC8P6pdm',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-68',
#   'who': 'i-HP26Ex6XfZD2gozC8P6pdm',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-69',
#   'who': 'i-HP26Ex6XfZD2gozC8P6pdm',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-70',
#   'who': 'i-XXHxxQRuSjGXVxaVhcXaFk',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-71',
#   'who': 'i-XXHxxQRuSjGXVxaVhcXaFk',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-72',
#   'who': 'i-XXHxxQRuSjGXVxaVhcXaFk',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-73',
#   'who': 'i-XXHxxQRuSjGXVxaVhcXaFk',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-74',
#   'who': 'i-XXHxxQRuSjGXVxaVhcXaFk',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-75',
#   'who': 'i-XXHxxQRuSjGXVxaVhcXaFk',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-76',
#   'who': 'i-XXHxxQRuSjGXVxaVhcXaFk',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-77',
#   'who': 'i-XXHxxQRuSjGXVxaVhcXaFk',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-78',
#   'who': 'i-XXHxxQRuSjGXVxaVhcXaFk',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-79',
#   'who': 'i-HP26Ex6XfZD2gozC8P6pdm',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-80',
#   'who': 'i-HP26Ex6XfZD2gozC8P6pdm',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-81',
#   'who': 'i-HP26Ex6XfZD2gozC8P6pdm',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-82',
#   'who': 'i-HP26Ex6XfZD2gozC8P6pdm',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-83',
#   'who': 'i-XXHxxQRuSjGXVxaVhcXaFk',
#   'role': 'mp',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-84',
#   'who': 'i-XXHxxQRuSjGXVxaVhcXaFk',
#   'role': 'mp',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-85',
#   'who': 'i-sS6VZTVNkCN6AHvZNaaYb',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-86',
#   'who': 'i-sS6VZTVNkCN6AHvZNaaYb',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-87',
#   'who': 'i-sS6VZTVNkCN6AHvZNaaYb',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-88',
#   'who': 'i-sS6VZTVNkCN6AHvZNaaYb',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-89',
#   'who': 'i-sS6VZTVNkCN6AHvZNaaYb',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-90',
#   'who': 'i-sS6VZTVNkCN6AHvZNaaYb',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-91',
#   'who': 'i-sS6VZTVNkCN6AHvZNaaYb',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-6BGaqNyUNFNsj56xvWXo5V',
#   'who': 'i-sS6VZTVNkCN6AHvZNaaYb',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-92',
#   'who': 'i-sS6VZTVNkCN6AHvZNaaYb',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-93',
#   'who': 'i-sS6VZTVNkCN6AHvZNaaYb',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-94',
#   'who': 'i-sS6VZTVNkCN6AHvZNaaYb',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-95',
#   'who': 'i-sS6VZTVNkCN6AHvZNaaYb',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-96',
#   'who': 'i-sS6VZTVNkCN6AHvZNaaYb',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-97',
#   'who': 'i-sS6VZTVNkCN6AHvZNaaYb',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-98',
#   'who': 'i-J74sVAjCTSxzD8rbnxRRA',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-99',
#   'who': 'i-J74sVAjCTSxzD8rbnxRRA',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-100',
#   'who': 'i-J74sVAjCTSxzD8rbnxRRA',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-101',
#   'who': 'i-J74sVAjCTSxzD8rbnxRRA',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-102',
#   'who': 'i-J74sVAjCTSxzD8rbnxRRA',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-103',
#   'who': 'i-J74sVAjCTSxzD8rbnxRRA',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-104',
#   'who': 'i-J74sVAjCTSxzD8rbnxRRA',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-105',
#   'who': 'i-J74sVAjCTSxzD8rbnxRRA',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-106',
#   'who': 'i-J74sVAjCTSxzD8rbnxRRA',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-107',
#   'who': 'i-sS6VZTVNkCN6AHvZNaaYb',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-108',
#   'who': 'i-sS6VZTVNkCN6AHvZNaaYb',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-109',
#   'who': 'i-sS6VZTVNkCN6AHvZNaaYb',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-110',
#   'who': 'i-sS6VZTVNkCN6AHvZNaaYb',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-112',
#   'who': 'i-sS6VZTVNkCN6AHvZNaaYb',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-113',
#   'who': 'i-sS6VZTVNkCN6AHvZNaaYb',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-114',
#   'who': 'i-sS6VZTVNkCN6AHvZNaaYb',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-115',
#   'who': 'i-sS6VZTVNkCN6AHvZNaaYb',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-116',
#   'who': 'i-sS6VZTVNkCN6AHvZNaaYb',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-117',
#   'who': 'i-sS6VZTVNkCN6AHvZNaaYb',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-118',
#   'who': 'i-sS6VZTVNkCN6AHvZNaaYb',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-119',
#   'who': 'i-J74sVAjCTSxzD8rbnxRRA',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-120',
#   'who': 'i-J74sVAjCTSxzD8rbnxRRA',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-121',
#   'who': 'i-J74sVAjCTSxzD8rbnxRRA',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-122',
#   'who': 'i-J74sVAjCTSxzD8rbnxRRA',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-123',
#   'who': 'i-J74sVAjCTSxzD8rbnxRRA',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-124',
#   'who': 'i-J74sVAjCTSxzD8rbnxRRA',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-125',
#   'who': 'i-J74sVAjCTSxzD8rbnxRRA',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-126',
#   'who': 'i-J74sVAjCTSxzD8rbnxRRA',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-127',
#   'who': 'i-J74sVAjCTSxzD8rbnxRRA',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-128',
#   'who': 'i-sS6VZTVNkCN6AHvZNaaYb',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-129',
#   'who': 'i-sS6VZTVNkCN6AHvZNaaYb',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-130',
#   'who': 'i-sS6VZTVNkCN6AHvZNaaYb',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-131',
#   'who': 'i-sS6VZTVNkCN6AHvZNaaYb',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-132',
#   'who': 'i-sS6VZTVNkCN6AHvZNaaYb',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-133',
#   'who': 'i-sS6VZTVNkCN6AHvZNaaYb',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-134',
#   'who': 'i-sS6VZTVNkCN6AHvZNaaYb',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-135',
#   'who': 'i-sS6VZTVNkCN6AHvZNaaYb',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-136',
#   'who': 'i-sS6VZTVNkCN6AHvZNaaYb',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-137',
#   'who': 'i-sS6VZTVNkCN6AHvZNaaYb',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-138',
#   'who': 'i-sS6VZTVNkCN6AHvZNaaYb',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-139',
#   'who': 'i-J74sVAjCTSxzD8rbnxRRA',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-140',
#   'who': 'i-J74sVAjCTSxzD8rbnxRRA',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-141',
#   'who': 'i-J74sVAjCTSxzD8rbnxRRA',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-142',
#   'who': 'i-J74sVAjCTSxzD8rbnxRRA',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-143',
#   'who': 'i-J74sVAjCTSxzD8rbnxRRA',
#   'role': 'mp',
#   'label': 'question/remark'},
#  {'id': 'i-e1bac02d35b800f5-144',
#   'who': 'i-sS6VZTVNkCN6AHvZNaaYb',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-145',
#   'who': 'i-sS6VZTVNkCN6AHvZNaaYb',
#   'role': 'minister',
#   'label': 'answer'},
#  {'id': 'i-e1bac02d35b800f5-146',
#   'who': 'i-sS6VZTVNkCN6AHvZNaaYb',
#   'role': 'minister',
#   'label': 'answer'}]

# %% [markdown]
# for the whole corpus

# %%
import os
import csv
from lxml import etree
from tqdm import tqdm

def parse_utterances(root, new_df):
    NS = {"tei": "http://www.tei-c.org/ns/1.0"}

    def get_role(who_id):
        role = new_df.loc[new_df["person_id"] == who_id, "role_category"]
        return role.values[0].lower() if not role.empty else "unknown"

    all_utterances = []

    for section in root.findall(".//tei:div[@type='debateSection']", namespaces=NS):
        utterances = section.findall(".//tei:u", namespaces=NS)
        for u in utterances:
            u_id = u.attrib.get("xml:id") or u.attrib.get("{http://www.w3.org/XML/1998/namespace}id")
            who = u.attrib.get("who")
            role = get_role(who)

            all_utterances.append({
                "id": u_id,
                "who": who,
                "role": role,
            })

        all_utterances.append({
            "id": None,
            "who": None,
            "role": "section_break",
        })

    return all_utterances

def label_utterances_exact(utterances):
    labeled = []

    for i, utt in enumerate(utterances):
        role = utt["role"]
        who = utt["who"]

        if role == "section_break":
            labeled.append({**utt, "label": None})
            continue

        label = "question/remark"
        if role == "minister":
            label = "answer"
        else:
            for j in range(i + 1, len(utterances)):
                next_utt = utterances[j]
                if next_utt["role"] == "section_break":
                    label = "answer"
                    break
                elif next_utt["role"] == "mp" and next_utt["who"] != who:
                    label = "answer"
                    break
                elif next_utt["role"] == "minister":
                    break

        labeled.append({**utt, "label": label})

    return [u for u in labeled if u["role"] != "section_break"]

def extract_year_from_path(filepath):
    filename = os.path.basename(filepath)
    year_str = filename.split("-")[1][:4]
    return int(year_str)

def process_protocols(new_df, protocols, output_csv="identified_answers.csv"):
    parser = etree.XMLParser(encoding='utf-8')
    answers = []

    for path in tqdm(protocols):
        try:
            root = etree.parse(path, parser).getroot()
            year = extract_year_from_path(path)

            utterances = parse_utterances(root, new_df)
            labeled = label_utterances_exact(utterances)

            for utt in labeled:
                if utt["label"] == "answer":
                    answers.append({
                        "utterance_id": utt["id"],
                        "year": year,
                        "who": utt["who"],
                        "role": utt["role"]
                    })
        except Exception as e:
            print(f"Failed on {path}: {e}")

    # Save to CSV
    with open(output_csv, mode="w", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=["utterance_id", "year", "who", "role"])
        writer.writeheader()
        writer.writerows(answers)

# %%
from pyriksdagen.utils import corpus_iterator

protocols = list(corpus_iterator(document_type="prot", corpus_root="data/", start=1867, end=2023))
process_protocols(new_df, protocols, output_csv="identified_answers.csv")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 17938/17938 [4:48:04<00:00,  1.04it/s]

# %%
import pandas as pd
from tqdm import tqdm

def count_distinct_answers_with_progress(csv_path):
    df = pd.read_csv(csv_path)

    def split_id(utt_id):
        if pd.isna(utt_id):
            return None, None
        if '-' in utt_id:
            prefix, suffix = utt_id.rsplit('-', 1)
            if suffix.isdigit():
                return prefix, int(suffix)
        return utt_id, None

    df = df.sort_values(by=["year", "utterance_id"]).reset_index(drop=True)

    counts = {}
    prev = None
    
    for _, row in tqdm(df.iterrows(), total=len(df), desc="Counting answers"):
        year = row["year"]
        who = row["who"]
        role = row["role"]
        utt_id = row["utterance_id"]

        prefix, suffix = split_id(utt_id)
        counts.setdefault(year, 0)

        if prev is None:
            counts[year] += 1
            prev = (prefix, suffix, who, role)
            continue

        prev_prefix, prev_suffix, prev_who, prev_role = prev

        if who != prev_who or role != prev_role:
            counts[year] += 1
        elif prefix != prev_prefix:
            counts[year] += 1
        else:
            if suffix is None or prev_suffix is None or suffix != prev_suffix + 1:
                counts[year] += 1
            else:
                pass

        prev = (prefix, suffix, who, role)

    return counts

# %%
csv_file = "identified_answers.csv"
answer_counts = count_distinct_answers_with_progress(csv_file)

print("Distinct answer counts per year:")
for year, count in sorted(answer_counts.items()):
    print(f"{year}: {count}")
# Out:
# Counting answers: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4160226/4160226 [02:57<00:00, 23395.20it/s]
# Distinct answer counts per year:
# 1867: 17052
# 1868: 17024
# 1869: 16985
# 1870: 14588
# 1871: 18993
# 1872: 15381
# 1873: 16877
# 1874: 13219
# 1875: 20331
# 1876: 18431
# 1877: 18539
# 1878: 19453
# 1879: 15934
# 1880: 16197
# 1881: 11850
# 1882: 17133
# 1883: 16131
# 1884: 12199
# 1885: 15902
# 1886: 17275
# 1887: 12881
# 1888: 16047
# 1889: 18360
# 1890: 15706
# 1891: 14517
# 1892: 17095
# 1893: 13708
# 1894: 17022
# 1895: 15607
# 1896: 16740
# 1897: 15838
# 1898: 17073
# 1899: 13068
# 1910: 24657
# 1911: 25990
# 1912: 25587
# 1913: 26931
# 1914: 22027
# 1915: 20618
# 1916: 20049
# 1917: 27072
# 1918: 32178
# 1919: 31716
# 1924: 1335
# 1951: 77
# 1971: 13328
# 1972: 15772
# 1973: 14403
# 1974: 12195
# 1975: 41974
# 1976: 29940
# 1977: 30303
# 1978: 19067
# 1979: 16946
# 1980: 14982
# 1981: 16484
# 1982: 14716
# 1983: 16206
# 1984: 16242
# 1985: 15018
# 1986: 16004
# 1987: 16317
# 1988: 16178
# 1989: 16798
# 1990: 40501
# 1991: 39309
# 1992: 43599
# 1993: 40435
# 1994: 30515
# 1995: 25203
# 1996: 32379
# 1997: 34611
# 1998: 28975
# 1999: 33556
# 2000: 34992
# 2001: 35294
# 2002: 30350
# 2003: 23936
# 2004: 27946
# 2005: 25708
# 2006: 26899
# 2007: 32037
# 2008: 29351
# 2009: 25740
# 2010: 24205
# 2011: 25024
# 2012: 26477
# 2013: 30520
# 2014: 26133
# 2015: 27384
# 2016: 24715
# 2017: 25112
# 2018: 18438
# 2019: 20081
# 2020: 29737
# 2021: 65537
# 2022: 73248

# %%
import matplotlib.pyplot as plt

years = sorted(answer_counts.keys())
counts = [answer_counts[year] for year in years]

plt.figure(figsize=(15,6))
plt.plot(years, counts, marker='o', linestyle='-', color='b')

plt.title("Distinct Answer Counts Per Year")
plt.xlabel("Year")
plt.ylabel("Number of Answers")
plt.grid(True)
plt.tight_layout()

plt.savefig("answer_counts_per_year.png")
